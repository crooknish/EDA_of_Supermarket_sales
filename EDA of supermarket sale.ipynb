# %% [markdown]
# # Exploratory Data Analysis of Supermarket sales
# ## By - Nishant kumar (20113105)
# ## Under - Prof. Siddharth Khare

# %% [markdown]
# >Importing necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# >Reading the csv file

# %%
data = pd.read_csv('supermarket_sales - Sheet1.csv',parse_dates=['Date'])

# %% [markdown]
# >Ignoring warnings

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# >Displaying first 5 data of the data sheet

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
data.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6

# %%
data.shape
# Out:
# (1000, 17)

# %%
print("Number of columns", data.shape[0])
print("Number of rows", data.shape[1])
# Out:
# Number of columns 1000
# Number of rows 17

# %% [markdown]
# >Finding the null data in the data sheet

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# >Getting the info of the data types and null cont count of the various columns of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(8)
# memory usage: 132.9+ KB

# %% [markdown]
# >Gettting the mean, standar deviation, count, min, max and many more info regarding the various float datatypes of the dataset

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %% [markdown]
# >Dividing the columns into categories and numericals data types

# %%
cat=[]
num=[]
for column in data.columns:
    if data[column].nunique()>10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# ## 1.Univariate analysis

# %% [markdown]
# ### Categorical

# %% [markdown]
# >Displaying the numbers of different branches using pie chart

# %%
data['Branch'].value_counts().plot(kind="pie",autopct="%1.2f%%")
plt.title('Number of branches')
# Out:
# Text(0.5, 1.0, 'Number of branches')

# %% [markdown]
# Here we can see that the percentage of Branch A is greater than Branch B and C

# %% [markdown]
# >Displaying number of different branches using barchart

# %%
data['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
data['Branch'].value_counts().plot(kind="bar")
plt.title('Number of branches')
# Out:
# Text(0.5, 1.0, 'Number of branches')

# %% [markdown]
# In the Bar chart, we can also see that number of Branch A is greater than that of number of branch B and C.

# %%
data['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
data['Payment'].value_counts().plot(kind="bar")
plt.title('Mode of payment')
# Out:
# Text(0.5, 1.0, 'Mode of payment')

# %% [markdown]
# Mode of payment by Ewallet and cash is almost same and by credit card is less. Number of payments by E-wallets is 345 and number of payments by credit card is 311. That shows that customers prefer to pay through cash and E-wallets as compared to credit card.

# %% [markdown]
# ### Numerical

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %% [markdown]
# >Plotting the distribution of Ratings

# %%
sns.distplot(data['Rating'])
plt.title('Distribution of rating')
# Out:
# Text(0.5, 1.0, 'Distribution of rating')

# %% [markdown]
# By the distribution graph of Rating, we can find that the ratings are normally distributed and the skewness is also almost equal to zero i.e. the distribution is symmetrical from both side.

# %%
data['Rating'].skew()
# Out:
# 0.00900964876573073

# %% [markdown]
# >Plotting the distribution of cost of goods sold (cogs)

# %%
sns.distplot(data['cogs'])
plt.title('Distribution of cogs')
# Out:
# Text(0.5, 1.0, 'Distribution of cogs')

# %% [markdown]
# Here we can see that data is right skewed. In other words, the majority of the data is concentrated on the left side of the distribution, with a few high values on the right side. The number of low cogs is more than that of number of high cogs. We can find the probability of the particular cogs by KDE(Kernel density estimation). For example- probability of cogs 400 is approximately 0.1 %

# %%
data['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
data['cogs'].describe()
# Out:
# count    1000.00000
# mean      307.58738
# std       234.17651
# min        10.17000
# 25%       118.49750
# 50%       241.76000
# 75%       448.90500
# max       993.00000
# Name: cogs, dtype: float64

# %%
print("Median of cost of goods(cogs)- ",data['cogs'].median())
# Out:
# Median of cost of goods(cogs)-  241.76

# %% [markdown]
# We have found the mean, median, std, min and max of cogs.

# %%
sns.boxplot(data['cogs'])
plt.title('Box Plot of cog')
# Out:
# Text(0.5, 1.0, 'Box Plot of cog')

# %% [markdown]
# In this box plot, we can se the minimun and maximum value of cogs. the middle line in the blue box denotes the median of the cogs i.e 241. The lower bound of the box denotes the 1st quartile i.e the 25% of value lies between minimum and 1st quartile value. The upper bound of box denotes 3rd quartile. We have outliers over upper bound (above 1.5 times IQR(inter-quartile ratio)) which denotes extreme values, or the presence of an entirely different underlying process.

# %% [markdown]
# ## 2. Bivariate analysis

# %% [markdown]
# ### Numerical-Numerical

# %% [markdown]
# >scatter plot of gross income and cogs

# %%
sns.scatterplot(data = data,x="gross income",y="cogs")
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='cogs'>

# %% [markdown]
# By the scatterplot betweeen gross income and cogs, we can see that there is direct relationship between the gross income and cogs. As the cogs is increased, the gross income on that sale is also get increased.

# %% [markdown]
# ### Categorical-Numerical

# %% [markdown]
# >Bar plot of Branch with gross income

# %%
sns.barplot(data=data,x="Branch",y="gross income")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# By the bar chart, we compare the gross income from various branches. The gross income from branch C is the highest and gross income from branch A is lowest.

# %% [markdown]
# #### Relationship with Gender and gross income

# %%
sns.boxplot(data=data, x="Gender", y="gross income")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# By this, we can see that the gross income from both male and female consumers are equal. But female consumers spend a little bit more as compared to male consumers.

# %% [markdown]
# #### Product line which generates most gross income

# %%
sns.barplot(data=data,x="Product line", y="gross income")
plt.title('Product line which generate most gross income')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# The Home and lifestyle product line generates highest gross income among all the product line and Fashion accessories generates the lowest.

# %% [markdown]
# #### Product line vs Unit price

# %%
sns.barplot(data=data,x="Product line", y="Unit price")
plt.title('Unit price vs Product line')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# The highest unit price is of fashion accessories and sports and travel product line.

# %% [markdown]
# ### Categorical-Categorical

# %% [markdown]
# >Different payment methods used by customer citywise

# %%
pd.crosstab(data['City'],data['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(data['City'],data['Payment']))
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='City'>

# %% [markdown]
# The consumers from city Naypyitaw pay more in cash and least by credit card. The consumers of City Mandalay uses almost all methods of payment equally.

# %% [markdown]
# #### Which product line is purchased in the highest quantity

# %%
(data.groupby('Product line').sum()['Quantity']).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Product line'>

# %% [markdown]
# Here we can see that electronic accessories has been purchased in highest quantity

# %% [markdown]
# #### Display daily sales by day of the week

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
 dw_mapping={
     0:'Mon',
     1:'Tue',
     2:'Wed',
     3:'Thur',
     4:'Fri',
     5:'Sat',
     6:'Sun'
 }

# %%
data['day_of_week']=data['Date'].dt.dayofweek.map(dw_mapping)

# %%
data['day_of_week'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Saturday has the highest number of daily sales and Monday has the lowest daily sales.

# %% [markdown]
# ## 3. Multivariate Analysis

# %%
sns.barplot(data=data,x="Branch",y="gross income",hue="City")
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# By the bar plot, we see can see the different branches in different cities. Branch B which is in Naypyitaw has the highest gross income and Branch A which is in the city Yangon has the lowest gross income.As we have seen earlier, number of branch A is also more than branch B and C. This means that we should have take some important measures to increase the gross income in the City Yangon.

# %%
sns.boxplot(data=data, x="Gender", y="gross income", hue="Customer type")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# By this, we see that female member consumer spend more than normal male or female consumer.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# 1)- We have to make our focus on city Yangon as it has the most number of branches but still generates low gross income as compared to others.

# %% [markdown]
# 2)- We have to spend less on fashion accessories as its unit price is high but generates lowest gross income.

# %% [markdown]
# 3)- We have to take care of female member consumer as they are important part of total gross income of supermarket.

# %% [markdown]
# 4)- Try to convert normal consumer to member consumer.

# %% [markdown]
# 5)- Be ready for the high sale in Saturday and try to attract more consumer on Sunday and Monday.
